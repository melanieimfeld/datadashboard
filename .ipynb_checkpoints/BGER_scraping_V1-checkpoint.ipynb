# %%
#https://stackoverflow.com/questions/47944782/r-data-scraping-crawling-with-dynamic-multiple-urls
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re

# %%
import locale, datetime #for stringparsing in german
locale.setlocale(locale.LC_ALL, "de_de")
# Out:
# 'de_de'

# %% [markdown]
# **Extracting the index leading to mandate**

# %%
#highlight_docid=atf%3A%2F%2F95-IV-162
queryKeyword = "drogen"
queryRank = "1"
#bgerQuery2 = "https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&type=highlight_simple_query&page=1&from_date=&to_date=&from_year=1954&to_year=2019&sort=relevance&insertion_date=&from_date_push=&top_subcollection_clir=bge&query_words="+ queryKeyword + "&part=all&de_fr=&de_it=&fr_de=&fr_it=&it_de=&it_fr=&orig=&translation=&rank="+queryRank+"&highlight_docid=atf%3A%2F%2F95-IV-162%3Ade&number_of_ranks=945&azaclir=clir"

# %%
bgerQuery2 = 'https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&type=simple_query&query_words='+ queryKeyword +'&lang=de&top_subcollection_clir=bge&from_year=1954&to_year=2019'

# %%
bgerQuery2
# Out:
# 'https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&type=simple_query&query_words=drogen&lang=de&top_subcollection_clir=bge&from_year=1954&to_year=2019'

# %%
#check if content was loaded properly
bgerQuery2 = requests.get(bgerQuery2)
bgerQuery2
# Out:
# <Response [200]>

# %%
#bgerQuery2.content

# %%
#soup = BeautifulSoup(page.content, 'html.parser')

# %%
bgerSoup = BeautifulSoup(bgerQuery2.content, 'html.parser')

# %%
bgerSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="de">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width initial-scale=1" name="viewport"/>
# <link href="/modules/tfl-internet-templates/images/favicon.ico" rel="icon"/>
# <title>Eurospider Suche: drogen</title>
# <link href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/css/master.css" rel="stylesheet" title="Eurospider Default Screen Style" type="text/css"/>
# <link href="/modules/tfl-internet-templates/css/styles.css" media="screen" rel="stylesheet" type="text/css"/>
# <style media="print" type="text/css">
#         @media print{
#             .body .size1of3{
#                 display: none;
#             }
#             .head .grid_left{
#                 display: none;
#             }
#             .access-a, .form-search, .define-admin {
#                 display: none !important;
#             }
#             body{
#                 font-family: Arial, sans-serif;
#                 font-size: 12px !important;
#             }
#             p, li, div, span{
#
#             }
#             a{
#                 color: black;
#                 text-decoration: none;
#             }
#             .modContent h1:first-child {
#                 margin-top: .071em;
#                 font-weight: normal;
#             }
#             .modContent h2:first-child {
#                 margin-top: .429em;
#             }
#             .modContent h2:first-child strong{
#                 font-weight: normal;
#             }
#             .richtext .leg {
#                 line-height: 1.538;
#                 margin-bottom: 5px;
#             }
#             .retour{
#                 display: none;
#             }
#             body .desktop-logo{
#
#             }
#             body .mobile-logo{
#                 display: none !important;
#             }
#
#         }
#
#     </style>
# <script type="text/javascript">
#
#         var msg="Bitte erklären Sie sich mit unseren Geschäftsbedingungen einverstanden.";
#
#     </script>
# </head></html>
# <script type="text/javascript">
# var contextJsParameters={contextPath:"",lang:"de",uilang:"de",siteUuid:"1b49b4f5-ee91-476d-beb4-bb6e8025abad",wcag:true,ckeCfg:""}; var CKEDITOR_BASEPATH="/modules/ckeditor/javascript/"; var scayt_custom_params=new Array(); scayt_custom_params['sLang']='de_DE';
# </script>
# <script id="staticAssetJavascript0" src="/generated-resources/86f16633e22e57d9b9e91be9a5848b42.min.js" type="text/javascript"></script>
# <script id="staticAssetAggregatedJavascriptList0" type="text/javascript">
# var jASAJ=jASAJ || new Array();
# jASAJ.push('/modules/jquery/javascript/jquery.min.js');
# jASAJ.push('/modules/assets/javascript/jquery.jahia.min.js');
# </script>
#
# <body class="skinLeft content-page" id="content-page">
# <div class="wrapper overflowx">
# <div class="opacity"></div>
# <div class="bodywrapper">
# <a aria-hidden="true" class="hiddenanchor" name="start"></a>
# <header class="head" id="banner" role="banner">
# <div class="line line_head">
# <div class="unit size1of3">
# <div class="mod modLogo" data-connectors="MasterSlave1Master">
# <div class="inner">
# <a accesskey="0" class="desktop-logo" href="/index.htm" target="_top" title="Homepage">
# <img alt="Homepage" height="189" src="/files/live/sites/bger/files/images/de/schweizerisches-bundesgericht-logo.gif" width="300"/>
# </a>
# <a accesskey="0" class="mobile-logo" href="/index.htm" target="_top" title="Homepage">
# <img alt="Homepage" height="58" src="/files/live/sites/bger/files/images/de/mobile-schweizerisches-bundesgericht-logo.gif" width="71"/>
# </a><div class="clear"></div><div class="clear"></div>
# </div>
# </div>
# </div>
# <div class="unit size2of3 lastUnit grid_left">
# <div class="line">
# <div class="unit size2of3">
# <div class="mod modNavService">
# <div class="inner">
# <button aria-expanded="false" aria-haspopup="true" class="nav-mobile-icon" href="#" title="Das Menü">
# <span>menu</span>
# </button>
# <div class="nav">
# <nav aria-label="Navigation secondaire" id="mobile-navigation">
# <ul class="block" role="menu">
# <div class="home-menu-list">
# <li class="item">
# <a class="l1" href="/index/juridiction.htm">
# <span>Rechtsprechung</span>
# </a>
# <ul class="sub">
# <li>
# <a class="l2" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht.htm">
# <span>Rechtsprechung (gratis)</span>
# </a>
# <ul class="four-level">
# <li>
# <a class="l4" href="/ext/eurospider/live/de/php/clir/http/start_de.html">
# <span>BGE und EGMR-Entscheide</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/ext/eurospider/live/de/php/aza/http/index_aza.php?lang=de&amp;mode=index&amp;search=false">
# <span>Liste der Neuheiten</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/ext/eurospider/live/de/php/aza/http/index.php?lang=de">
# <span>Weitere Urteile ab 2000</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-urteilsbestellung.htm">
# <span>Urteilsbestellung</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/juridiction-digitalisation.htm">
# <span>Nummerierung der Dossiers</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-suchstrategie1954.htm">
# <span>Suchstrategie</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="l2" href="/ext/eurospider/live/de/php/clir/http/index.php?lang=de">
# <span>Leitentscheide (BGE)</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/ext/eurospider/live/de/php/login/http/main.php?lang=de">
# <span>Expertensuche für Abonnenten</span>
# </a>
# <ul class="four-level">
# <li>
# <a class="l4" href="/ext/eurospider/live/de/php/expert/http/index_aza.php?lang=de&amp;mode=index&amp;search=true">
# <span>Liste der Neuheiten</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht-kostenpflichtige-suche/jurisdiction-recht-zeitschriftenliste.htm">
# <span>Liste der Zeitschriften</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht-kostenpflichtige-suche/jurisdiction-recht-bge-kostenpflichtig-gratis.htm">
# <span>Suchstrategie</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="l2" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-abonnemente.htm">
# <span>Abonnemente/Bestellungen</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/juridiction/jurisdiction-inherit-template/federal-meeting.htm">
# <span>Sitzungen</span>
# </a>
# <ul class="four-level">
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/federal-meeting/federal-meeting-newsletter.htm">
# <span>Sitzungsliste abonnieren</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="l2" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-jurivoc-home.htm">
# <span>Jurivoc - Übersetzungshilfe</span>
# </a>
# <ul class="four-level">
# <li>
# <a class="l4" href="/ext/jurivoc/live/de/jurivoc/Jurivoc.jsp?interfaceLanguage=german">
# <span>Abfrage des Thesaurus Jurivoc</span>
# </a>
# </li>
# <li>
# <a class="l4" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction
span>
# </a>
# </li>
# </ul>
# </li>
# <li class="item new test">
# <a class="l1 mobile-menu" href="/index/help/help-inherit-template/help-hilfe.htm" target="_top">Hilfe</a>
# <ul class="sub thematic-sub">
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-suche-asp.htm">
# <span>Suche</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-recht.htm">
# <span>Sitemap Rechtsprechung</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-bger.htm">
# <span>Sitemap Bundesgericht</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-presse.htm">
# <span>Sitemap Presse/Aktuelles</span>
# </a>
# </li>
# </ul>
# </li>
# </div>
# </ul>
# </nav><div class="clear"></div><div class="nav-nav" id="tematic-menu" role="navigation">
# <ul class="block thematic-block">
# <li class="item item_first">
# <a href="/index/federal/federal-inherit-template/gericht-elektronischer-verkehr.htm" target="_top">Elektronischer Verkehr</a>
# <ul class="sub thematic-sub">
# </ul>
# </li>
# <li class="item ">
# <a href="/index/federal/federal-inherit-template/insurance-federal-jobs.htm" target="_top">Stellen</a>
# <ul class="sub thematic-sub">
# </ul>
# </li>
# <li class="item ">
# <a href="/index/contact/contact-inherit-template/contact-adressen-bger.htm" target="_top">Kontakt</a>
# <ul class="sub thematic-sub">
# </ul>
# </li>
# <li class="item ">
# <a href="/index/help/help-inherit-template/help-hilfe.htm" target="_top">Hilfe</a>
# <ul class="sub thematic-sub">
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-suche-asp.htm">
# <span>Suche</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-recht.htm">
# <span>Sitemap Rechtsprechung</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-bger.htm">
# <span>Sitemap Bundesgericht</span>
# </a>
# </li>
# <li>
# <a class="l2" href="/index/help/help-inherit-template/help-hilfe/help-hilfe-sitemap-presse.htm">
# <span>Sitemap Presse/Aktuelles</span>
# </a>
# </li>
# </ul>
# </li>
# </ul>
# </div><div class="clear"></div><p class="invisible" id="change-lang">Changer la langue</p>
# <ul aria-labelledby="change-lang" class="block block_last language-block">
# <li class="item item_first">
# <p id="change-lang_de_to_fr">
# <a href="/fr/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-leitentscheide1954.htm" lang="fr" target="_top" title="Français">
# <span class="francais-lang-i">F</span>
# </a>
# </p>
# </li>
# <li class="item">
# <p id="change-lang_de_to_it">
# <a href="/it/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-leitentscheide1954.htm" lang="it" target="_top" title="Italiano">
# <span class="italiano-lang-i">I</span>
# </a>
# </p>
# </li>
# </ul><div class="clear"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="unit size1of3 lastUnit">
# <div class="mod modSearch">
# <div class="inner">
# <form action="/index/help/help-inherit-template/help-hilfe/help-hilfe-suche-asp.htm" class="simplesearchform" method="post" name="searchForm">
# <input name="jcrMethodToCall" type="hidden" value="get"/>
# <input name="src_originSiteKey" type="hidden" value="bger"/>
# <input class="text" id="search" name="src_terms[0].term" onblur="if(this.value=='')this.value='Suche';" onfocus="if(this.value=='Suche')this.value='';" placeholder="Suche" title="Suche" type="text" value=""/>
# <input name="src_terms[0].applyFilter" type="hidden" value="true"/>
# <input name="src_terms[0].match" type="hidden" value="all_words"/>
# <input name="src_terms[0].fields.siteContent" type="hidden" value="true"/>
# <input name="src_terms[0].fields.tags" type="hidden" value="true"/>
# <input name="src_terms[0].fields.files" type="hidden" value="true"/>
# <input name="src_sites.values" type="hidden" value="bger"/>
# <input name="src_sitesForReferences.values" type="hidden" value="systemsite"/>
# <input name="src_languages.values" type="hidden" value="de"/>
# <button class="submit" title="Suche aktivieren" type="submit" value="">Suche aktivieren</button>
# </form><br class="clear"/><div class="clear"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="line">
# <nav aria-label="Navigation principale" id="top-menu" role="navigation">
# <div class="mod modNavMain">
# <div class="inner">
# <ul>
# <li class="item first active">
# <a href="/index/juridiction.htm" target="_parent">
#                 Rechtsprechung
#         </a>
# </li>
# <li class="item">
# <a href="/index/federal.htm" target="_parent">
#                 Bundesgericht
#         </a>
# </li>
# <li class="item">
# <a href="/index/press.htm" target="_parent">
#                 Presse/Aktuelles
#         </a>
# </li>
# </ul>
# </div>
# </div>
# </nav><div class="clear"></div><div class="clear"></div>
# </div>
# </div>
# </div>
# </header>
# </div>
# <form class="form-search">
# <p class="form-search_p">
# <input class="form-search__field" id="form-search__field" placeholder="Suche" title="Suche" type="text" value=""/>
# </p>
# </form>
# <div class="page">
# <div class="absolute"></div>
# <div class="preloader"> </div>
# <div class="body">
# <div class="line overflow">
# <div class="unit size1of3">
# <nav aria-label="Navigation secondaire" id="left-menu" role="navigation">
# <!-- h2 class="invisible">Navigation secondaire</h2 -->
# <div class="mod modNavSub left-navi">
# <div class="inner">
# <ul>
# <li class="item">
# <a class="l1 active" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht.htm">
# <span>Rechtsprechung (gratis)</span>
# </a>
# </li>
# <ul class="sub">
# <li>
# <a class="l2 active" href="/ext/eurospider/live/de/php/clir/http/start_de.html">
# <span>BGE und EGMR-Entscheide</span>
# </a>
# </li>
# <li>
# <a class="l2 " href="/ext/eurospider/live/de/php/aza/http/index_aza.php?lang=de&amp;mode=index&amp;search=false">
# <span>Liste der Neuheiten</span>
# </a>
# </li>
# <li>
# <a class="l2 " href="/ext/eurospider/live/de/php/aza/http/index.php?lang=de">
# <span>Weitere Urteile ab 2000</span>
# </a>
# </li>
# <li>
# <a class="l2 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-urteilsbestellung.htm">
# <span>Urteilsbestellung</span>
# </a>
# </li>
# <li>
# <a class="l2 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/juridiction-digitalisation.htm">
# <span>Nummerierung der Dossiers</span>
# </a>
# </li>
# <li>
# <a class="l2 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht/jurisdiction-recht-suchstrategie1954.htm">
# <span>Suchstrategie</span>
# </a>
# </li>
# </ul>
# <li class="item">
# <a class="l1 " href="/ext/eurospider/live/de/php/clir/http/index.php?lang=de">
# <span>Leitentscheide (BGE)</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/ext/eurospider/live/de/php/login/http/main.php?lang=de">
# <span>Expertensuche für Abonnenten</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-abonnemente.htm">
# <span>Abonnemente/Bestellungen</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/federal-meeting.htm">
# <span>Sitzungen</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-jurivoc-home.htm">
# <span>Jurivoc - Übersetzungshilfe</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-zitierregeln.htm">
# <span>Zitierregeln</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-elektronische-beschwerde.htm">
# <span>Elektronische Beschwerde</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-echange-ecritures.htm">
# <span>Schriftenwechsel und freiwillige Bemerkungen</span>
# </a>
# </li>
# <li class="item">
# <a class="l1 " href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-certifications.htm">
# <span>Rechtskraftbescheinigungen / Bestätigungen</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav><div class="clear"></div><div class="clear"></div>
# </div>
# <main class="unit lastUnit size2of3 grid_left esigates" id="maincontent" role="main" tabindex="-1">
# <a aria-hidden="true" class="hiddenanchor" name="content"></a>
# <div class="eit">
# <div class="warning_msg" id="ns4_info">
#          Wichtiger Hinweis:
#          <br/>
#          Diese Website wird in älteren Versionen von Netscape ohne graphische Elemente dargestellt. Die Funktionalität der Website ist aber trotzdem gewährleistet. Wenn Sie diese Website regelmässig benutzen, empfehlen wir Ihnen, auf Ihrem Computer einen aktuellen Browser zu installieren.
#       </div>
# <div class="middle">
# <div align="left" style="float: left">
# <a class="noprint" href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?type=start&amp;lang=de" title="Zurück zur Einstiegsseite">Zurück zur Einstiegsseite</a>
# </div>
# <div align="right">
# <a class="noprint" href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;query_words=drogen&amp;top_subcollection_clir=bge&amp;from_year=1954&amp;to_year=2019&amp;zoom=YES&amp;" title="Grössere Schrift">Grössere Schrift</a>
# </div>
# </div>
# <div class="top">
# <div class="left">
#
#    </div>
# <div class="middle">
# <div id="search">
# <form action="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php" id="query_form" name="query_form">
# <fieldset>
# <legend class="big">BGE ab 1954 (publizierte Leitentscheide) und Urteile EGMR ab 1983</legend>
# <div id="search_form">
# <div id="search_form_data">
# <div id="search_form_data_first">
# <div id="search_input">
# <input name="lang" type="hidden" value="de">
# <input name="type" type="hidden" value="simple_query"/>
# <textarea class="big" cols="44" name="query_words" onkeypress="return submitOnEnter(event);" rows="3" title="Wörter der Suchanfrage">drogen</textarea>
# </input></div>
# <div id="search_options">
# <div class="search_option">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query" title="Suchformular löschen">Löschen</a>
# </div>
# <div class="search_option">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=help&amp;zoom=NO" title="Hilfe zur Suche">Hilfe</a>
# </div>
# </div>
# </div>
# <div id="search_form_data_second">
# <div id="search_restrictions">
# <div class="search_restriction">
# <table border="0">
# <tr>
# <td nowrap="true">
#                Suchen in:
#             </td>
# </tr>
# <tr>
# <td>
# <input checked="checked" class="top_subcollection" name="top_subcollection_clir" type="radio" value="bge"/>
#                Bundesgericht<br/>
# <input class="top_subcollection" name="top_subcollection_clir" type="radio" value="cedh"/>
#                Richterliche Behörden des Europarats<br/>
# <input class="top_subcollection" name="top_subcollection_clir" type="radio" value="all"/>
#                allen Urteilen<br/>
# </td>
# </tr>
# <tr>
# <td>
# <a class="more" href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?query_words=drogen&amp;part=all&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;lang=de&amp;type=simple_query&amp;azaclir=clir&amp;show_all=true&amp;azaclir=clir">mehr...</a>
# </td>
# </tr>
# </table>
# </div>
# <div class="search_restriction">
#       Zwischen:
#       <select name="from_year">
# <option selected="selected" value="1954">1954</option>
# <option value="1955">1955</option>
# <option value="1956">1956</option>
# <option value="1957">1957</option>
# <option value="1958">1958</option>
# <option value="1959">1959</option>
# <option value="1960">1960</option>
# <option value="1961">1961</option>
# <option value="1962">1962</option>
# <option value="1963">1963</option>
# <option value="1964">1964</option>
# <option value="1965">1965</option>
# <option value="1966">1966</option>
# <option value="1967">1967</option>
# <option value="1968">1968</option>
# <option value="1969">1969</option>
# <option value="1970">1970</option>
# <option value="1971">1971</option>
# <option value="1972">1972</option>
# <option value="1973">1973</option>
# <option value="1974">1974</option>
# <option value="1975">1975</option>
# <option value="1976">1976</option>
# <option value="1977">1977</option>
# <option value="1978">1978</option>
# <option value="1979">1979</option>
# <option value="1980">1980</option>
# <option value="1981">1981</option>
# <option value="1982">1982</option>
# <option value="1983">1983</option>
# <option value="1984">1984</option>

# </div>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="right">
#
#    </div>
# </div>
# <div class="main">
# <div class="left">
#
#    </div>
# <div class="middle">
# <div class="box" id="ranklist_exact">
# <div class="box_top_line"></div>
# <div class="box_top_2ndline"></div>
# <div class="content">
# <div class="ranklist_header center">
#                            119 exakte Treffer gefunden für <span class="bold">drogen</span>
# </div>
# <div class="ranklist_content big bold">
# <ol start="1">
# <li>
# <span class="rank_title">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=1&amp;highlight_docid=atf%3A%2F%2F107-IV-3%3Ade&amp;number_of_ranks=119&amp;azaclir=clir" title="Seite mit hervorgehobenen Suchbegriffen öffnen">107 IV 3</a>
# </span>
# <div class="rank_relevance">
# <img alt="Relevanz" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# </div>
# <div class="rank_data">
# <div class="urt small normal">
#       2. Auszug aus dem Urteil des Kassationshofes vom 20. Januar 1981 i.S. K. gegen Staatsanwaltschaft des Kantons Appenzell A. Rh. (Nichtigkeitsbeschwerde).
#    </div>
# <div class="regeste small normal">
#       Regeste
#       [<a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=1&amp;highlight_docid=atf%3A%2F%2F107-IV-3%3Ade%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">D</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=1&amp;highlight_docid=atf%3A%2F%2F107-IV-3%3Afr%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">F</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=1&amp;highlight_docid=atf%3A%2F%2F107-IV-3%3Ait%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">I</a>]
#       Art. 10 f. StGB. Nicht jede durch den Konsum von Alkohol oder andern bewusstseins- und willensbeeinflussenden Drogen bewirkte kurzfristige Enthemmung oder Verdummung genügt, um die Zurechnungsfähigkeit herabzusetzen. Berücksichtigung des Verhaltens des ...
#    </div>
# </div> </li>
# <li>
# <span class="rank_title">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=2&amp;highlight_docid=atf%3A%2F%2F101-IV-354%3Ade&amp;number_of_ranks=119&amp;azaclir=clir" title="Seite mit hervorgehobenen Suchbegriffen öffnen">101 IV 354</a>
# </span>
# <div class="rank_relevance">
# <img alt="Relevanz" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# </div>
# <div class="rank_data">
# <div class="urt small normal">
#       84. Urteil des Kassationshofes vom 9. Oktober 1975 i.S. Staatsanwaltschaft des Kantons Zürich gegen Küderli.
#    </div>
# <div class="regeste small normal">
#       Regeste
#       [<a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=2&amp;highlight_docid=atf%3A%2F%2F101-IV-354%3Ade%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">D</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=2&amp;highlight_docid=atf%3A%2F%2F101-IV-354%3Afr%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">F</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=2&amp;highlight_docid=atf%3A%2F%2F101-IV-354%3Ait%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">I</a>]
# ...
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=8&amp;highlight_docid=atf%3A%2F%2F128-II-335%3Afr%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">F</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=8&amp;highlight_docid=atf%3A%2F%2F128-II-335%3Ait%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">I</a>]
#       Art. 14 Abs. 2 lit. c, Art. 16 Abs. 1 und Art. 17 Abs. 1bis SVG; Art. 30 Abs. 1 VZV; Sicherungsentzug des Führerausweises, Drogen- und Alkoholmissbrauch im Strassenverkehr, Abklärung der Fahreignung. Ein die momentane Fahrfähigkeit beeinträchtigender ko...
#    </div>
# </div> </li>
# <li>
# <span class="rank_title">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=9&amp;highlight_docid=atf%3A%2F%2F106-IB-395%3Ade&amp;number_of_ranks=119&amp;azaclir=clir" title="Seite mit hervorgehobenen Suchbegriffen öffnen">106 Ib 395</a>
# </span>
# <div class="rank_relevance">
# <img alt="Relevanz" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# </div>
# <div class="rank_data">
# <div class="urt small normal">
#       60. Auszug aus dem Urteil der II. öffentlichrechtlichen Abteilung vom 12. Dezember 1980 i.S. Sediva gegen Regierungsrat des Kantons Zürich (Verwaltungsgerichtsbeschwerde)
#    </div>
# <div class="regeste small normal">
#       Regeste
#       [<a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=9&amp;highlight_docid=atf%3A%2F%2F106-IB-395%3Ade%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">D</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=9&amp;highlight_docid=atf%3A%2F%2F106-IB-395%3Afr%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">F</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=9&amp;highlight_docid=atf%3A%2F%2F106-IB-395%3Ait%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">I</a>]
#       Entzug des Führerausweises wegen deliktischen Missbrauchs des Motorfahrzeuges (Art. 16 Abs. 3 lit. f SVG). 1. Notwendiger Zusammenhang zwischen der Verwendung des Motorfahrzeuges und der Begehung des Deliktes (hier bejaht für den Schmuggel von Drogen) (...
#    </div>
# </div> </li>
# <li>
# <span class="rank_title">
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=10&amp;highlight_docid=atf%3A%2F%2F122-IV-299%3Ade&amp;number_of_ranks=119&amp;azaclir=clir" title="Seite mit hervorgehobenen Suchbegriffen öffnen">122 IV 299</a>
# </span>
# <div class="rank_relevance">
# <img alt="Relevanz" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# <img alt="" class="relevance" src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/img/relevance_full.png" title="Relevanz 100%"/>
# </div>
# <div class="rank_data">
# <div class="urt small normal">
#       46. Urteil des Kassationshofes vom 26. September 1996 i.S. W. gegen Staatsanwaltschaft des Kantons Solothurn (Nichtigkeitsbeschwerde)
#    </div>
# <div class="regeste small normal">
#       Regeste
#       [<a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=10&amp;highlight_docid=atf%3A%2F%2F122-IV-299%3Ade%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">D</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=10&amp;highlight_docid=atf%3A%2F%2F122-IV-299%3Afr%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">F</a>,
#        <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=highlight_simple_query&amp;page=1&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=&amp;rank=10&amp;highlight_docid=atf%3A%2F%2F122-IV-299%3Ait%3Aregeste&amp;number_of_ranks=119&amp;azaclir=clir">I</a>]
#       Art. 63 StGB; Strafzumessung, Bedeutung des Reinheitsgrades von Drogen. Der Reinheitsgrad von Betäubungsmitteln kann für das Verschulden von Bedeutung sein. Handelt der Täter wissentlich mit ausgesprochen reinen Drogen, ist das Verschulden schwerer, han...
#    </div>
# </div> </li>
# </ol>
# </div>
# <div class="ranklist_footer">
# <div class="page_nav center">
#             Ergebnisseite:
#
#
#
#
#                1
#
#
#
#                <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=2&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 11 bis 20 anzeigen">2</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=3&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 21 bis 30 anzeigen">3</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=4&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 31 bis 40 anzeigen">4</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=5&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 41 bis 50 anzeigen">5</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=6&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 51 bis 60 anzeigen">6</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=7&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 61 bis 70 anzeigen">7</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=8&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 71 bis 80 anzeigen">8</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=9&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 81 bis 90 anzeigen">9</a>
# <a href="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&amp;type=simple_query&amp;page=2&amp;from_date=&amp;to_date=&amp;from_year=1954&amp;to_year=2019&amp;sort=relevance&amp;insertion_date=&amp;from_date_push=&amp;top_subcollection_clir=bge&amp;query_words=drogen&amp;part=all&amp;de_fr=&amp;de_it=&amp;fr_de=&amp;fr_it=&amp;it_de=&amp;it_fr=&amp;orig=&amp;translation=" title="Ränge 11 bis 20 anzeigen">Vorwärts</a>
# </div> </div>
# </div>
# <div class="box_bottom_2ndline"></div>
# <div class="box_bottom_line"></div>
# </div>
# </div>
# <div class="right">
# <div class="box" id="searchtip">
# <div class="box_top_line"></div>
# <div class="box_top_2ndline"></div>
# <div class="content">
# <h3 class="bold small">
#          Suchtipp
#       </h3>
# <p>
#
#
#
#                   In der Dokumentenansicht können Sie mit einem Tastendruck auf 'n' zur nächsten und mit 'p' zur vorherigen Fundstelle im Dokument springen.
#       </p>
# </div>
# <div class="box_bottom_2ndline"></div>
# <div class="box_bottom_line"></div>
# </div>
# <div id="copyright">
#    © 2008
#    <a href="http://www.eurospider.com/" target="_blank" title="Eurospider Information Technology AG">Eurospider Information Technology AG</a>
# </div>
# </div>
# </div>
# </div>
# <div class="retour-paragraf">
# <a class="retour" href="/index/juridiction/jurisdiction-inherit-template/jurisdiction-recht.htm" title="Rechtsprechung (gratis)">Back</a>
# </div>
# </main>
# </div>
# </div>
# </div>
# </div>
# <div class="define-admin">false</div>
# <script src="/modules/tfl-internet-templates/javascript/lib/jquery-3.1.1.min.js" type="text/javascript"></script>
# <script src="https://code.jquery.com/jquery-migrate-1.2.1.js"></script>
# <script src="/modules/tfl-internet-templates/javascript/owl.carousel.min.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/jquery.smoothZoom.min.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/data-table.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/index.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/form.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/jquery.dataTables.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#     $(document).ready(function() {
#         var lang = getLang();
#         var title = document.title;
#         var titleText;
#         if (lang === 'de') {
#             titleText = 'Schweizerisches Bundesgericht';
#         } else if (lang === 'fr') {
#             titleText = 'Tribunal fédéral';
#         } else if (lang === 'it') {
#             titleText = 'Tribunale Federale';
#         }
#         document.title = title + ' - ' + titleText;
#     })
# </script>
# <!-- Piwik -->
# <script type="text/javascript">
#     var _paq = _paq || [];
#     // tracker methods like "setCustomDimension" should be called before "trackPageView"
#     _paq.push(['trackPageView']);
#     _paq.push(['enableLinkTracking']);
#     (function() {
#         var u="https://www.bger.ch/analytics/piwik/";
#         _paq.push(['setTrackerUrl', u+'piwik.php']);
#         _paq.push(['setSiteId', '1']);
#         var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#         g.type='text/javascript'; g.async=true; g.defer=true; g.src=u+'piwik.js'; s.parentNode.insertBefore(g,s);
#     })();
# </script>
# <!-- End Piwik Code -->
# <script src="https://www.bger.ch/ext/eurospider/live/de/php/clir/http/javascript/eit.js" type="text/javascript"></script>
# <script src="/modules/tfl-internet-templates/javascript/script.js" type="text/javascript"></script>
# </body>

# %%
links = bgerSoup.find_all(class_='rank_title')
linksList = []
for a in links:
    linksList.append(a.find('a')['href'])
    #print(a)
print(linksList[0])
# Out:
# https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&type=highlight_simple_query&page=1&from_date=&to_date=&from_year=1954&to_year=2019&sort=relevance&insertion_date=&from_date_push=&top_subcollection_clir=bge&query_words=drogen&part=all&de_fr=&de_it=&fr_de=&fr_it=&it_de=&it_fr=&orig=&translation=&rank=1&highlight_docid=atf%3A%2F%2F107-IV-3%3Ade&number_of_ranks=119&azaclir=clir

# %% [markdown]
# **Make a new query with Linkslist (only based on first entry)**

# %%
mBger = requests.get(linksList[0])

# %%
#mBger.content

# %%
mBger = BeautifulSoup(mBger.content, 'html.parser')

# %%
#mBger

# %% [markdown]
# **display children / find correct html elements**

# %%
len(list(mBger.children))
#find body
body = list(mBger.children)[12]
len(list(body.children))
#body
# Out:
# 33

# %% [markdown]
# **get all required variables from verdict**

# %% [markdown]
# **dateparser for string dates**

# %%
text2 = "41. Urteil des Kassationshofes vom 5. Dezember 1969 i.S. Staatsanwaltschaft des Kantons Aargau gegen Brunner."

def parseDate(text):
    pattern = re.compile(r"""
        \d\d?   # one or two digits
        \.?
        \s?      # \s for space - one space after
        [a-z,ä,ö,ü]+  # at least one+ ascii letters (ignore case is use)set of characters that you wish to match / since + means ‘one or more repetitions’
        \s?      # one space after
        \d{4}   # four decimal digits = \d (year)
    """,re.IGNORECASE|re.VERBOSE)
    if (pattern.search(text)!= None):
        #print(pattern.search(text).group(), type(pattern.search(text).group()))
        dateStr = pattern.search(text).group()
        dateStr = dateStr.replace(".", "")
        dateStr = datetime.datetime.strptime(dateStr, "%d %B %Y")
        #dateStr = dateStr.strftime('%m/%d/%Y')
        return dateStr
    else:
        return 0 #make 0 if date can't be found

# %%
#ID of mandate
mID = body.find_all('div', class_="center pagebreak")[0].get_text()[:13]
#mandID

#referenced mandates
#without link
mRefs = body.find_all(class_="bgeref_err")
#with link
mRefsLinked = body.find_all(class_="bgeref_id")

#date:
mDate = body.find_all(class_="paraatf")[0].get_text()
#mDate = parseDate(mDate)
mDate = parseDate(mDate)
mDate

#links of liked reference mandates
linksListref = []
for a in mRefsLinked:
    linksListref.append(a['href'])

# %%
type(mDate)
# Out:
# datetime.datetime

# %%
def listing(elementlist):
    ar = []
    for item in elementlist:
        print(item.get_text())
        ar.append(item.get_text())
    print(ar)
    return ar

# %%
mRefs = listing(mRefs)
mRefsLinked = listing(mRefsLinked)
# Out:
# []
# BGE 102 IV 226
# ['BGE 102 IV 226']

# %%
"id", mID, "referenced mandates", mRefs, "referenced linked mandates", mRefsLinked, "date", mDate
# Out:
# ('id',
#  'BGE 107 IV 3 ',
#  'referenced mandates',
#  [],
#  'referenced linked mandates',
#  ['BGE 102 IV 226'],
#  'date',
#  datetime.datetime(1981, 1, 20, 0, 0))

# %% [markdown]
# **Save variables in dynamic dictionary**

# %%
l=['mID','mRefs','mRefsLinked','links','date']
objs = [mID,mRefs, mRefsLinked, linksListref, mDate]
mDict = {}
for i, val in enumerate(l):
    k= objs[i]
    mDict[val]=k
print(mDict, type(mDict))
# Out:
# {'mID': 'BGE 107 IV 3 ', 'mRefs': [], 'mRefsLinked': ['BGE 102 IV 226'], 'links': ['https://www.bger.ch/ext/eurospider/live/de/php/clir/http/index.php?lang=de&type=highlight_simple_query&page=1&from_date=&to_date=&from_year=1954&to_year=2019&sort=relevance&insertion_date=&from_date_push=&top_subcollection_clir=bge&query_words=drogen&part=all&de_fr=&de_it=&fr_de=&fr_it=&it_de=&it_fr=&orig=&translation=&rank=0&highlight_docid=atf%3A%2F%2F102-IV-225%3Ade&number_of_ranks=0&azaclir=clir#page226'], 'date': datetime.datetime(1981, 1, 20, 0, 0)} <class 'dict'>

# %%
#https://stackoverflow.com/questions/13575090/construct-pandas-dataframe-from-items-in-nested-dictionary
#pd.DataFrame.from_dict(mDict, orient='index')
